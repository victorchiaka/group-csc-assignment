# %% [markdown]
# # Student Performance Dataset Analysis
#
# This notebook contains basic steps for loading, exploring, cleaning, and analyzing the student performance dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv('student-por.csv')
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.isnull().sum()

# %%
df = df.drop_duplicates()

# %%
df[['G1', 'G2', 'G3']].describe()

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrates basic data loading, cleaning, and exploratory analysis using Python and Pandas.
